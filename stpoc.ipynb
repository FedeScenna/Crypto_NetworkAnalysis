# %%
import pandas as pd
from constants import stablecoins
from utils import create_graph
import plotly.graph_objects as go

# %%
graph_df = pd.read_csv("graph_data.csv")
df = pd.read_csv("st_return_data.csv")
df.replace({'stablecoin': {0: "Volátil", 1: "Paridad USD"}})
df.columns
# Out:
# Index(['time', 'coin', 'stablecoin', 'value'], dtype='object')

# %%
import plotly.express as px
fig = px.box(data_frame=df, x = "coin",y="value", color = "stablecoin", labels={"coin":"Activo", "value":"Retorno Logarítmico", "stablecoin":"Tipo de Activo"})
fig.show()

# %%
G = create_graph(graph_df, stablecoins)

# %%
for edge in G.edges():
    print(G.nodes[edge[0]]["type"])#['type']

# %%
for edge in G.edges():
    print(G.nodes[edge[0]]["type"])#['type']
# Out:
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# volatile
# ...

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['type']
    x1, y1 = G.nodes[edge[1]]['type']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['type']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       2 edge_y = []
#       3 for edge in G.edges():
# ----> 4     x0, y0 = G.nodes[edge[0]]['type']
#       5     x1, y1 = G.nodes[edge[1]]['type']
#       6     edge_x.append(x0)
#
# ValueError: too many values to unpack (expected 2)

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="Python code: <a href='https://plotly.com/python/network-graphs/'> https://plotly.com/python/network-graphs/</a>",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002 ) ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()

# %%
df.describe()
# Out:
#               corr
# count  2025.000000
# mean      0.324641
# std       0.258722
# min      -0.207258
# 25%       0.086754
# 50%       0.351002
# 75%       0.502357
# max       1.000000

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# coinfrom    ADA
# cointo      ADA
# corr        1.0
# Name: 0, dtype: object
# coinfrom        ALGO
# cointo           ADA
# corr        0.553742
# Name: 1, dtype: object
# coinfrom        ATOM
# cointo           ADA
# corr        0.544778
# Name: 2, dtype: object
# coinfrom         BCH
# cointo           ADA
# corr        0.487691
# Name: 3, dtype: object
# coinfrom         BNB
# cointo           ADA
# corr        0.402013
# Name: 4, dtype: object
# coinfrom         BSV
# cointo           ADA
# corr        0.407859
# Name: 5, dtype: object
# coinfrom         BTC
# cointo           ADA
# corr        0.475343
# Name: 6, dtype: object
# coinfrom         CRO
# cointo           ADA
# corr        0.414101
# Name: 7, dtype: object
# coinfrom        DASH
# cointo           ADA
# corr        0.419372
# Name: 8, dtype: object
# coinfrom         DOT
# cointo           ADA
# corr        0.449677
# Name: 9, dtype: object
# coinfrom         EOS
# cointo           ADA
# corr        0.538506
# ...
