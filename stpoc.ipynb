# %%
import pandas as pd

# %%
df = pd.read_csv("graph_data.csv")
# Out:
# {'ADA',
#  'ALGO',
#  'ATOM',
#  'BCH',
#  'BNB',
#  'BSV',
#  'BTC',
#  'BUSD',
#  'CRO',
#  'CTC',
#  'DAI',
#  'DASH',
#  'DOT',
#  'EOS',
#  'ETC',
#  'ETH',
#  'FTT',
#  'HEDG',
#  'HEX',
#  'HT',
#  'LEO',
#  'LINK',
#  'LTC',
#  'MIOTA',
#  'MKR',
#  'NEO',
#  'OKB',
#  'OMG',
#  'ONT',
#  'SNX',
#  'THETA',
#  'TRX',
#  'TUSD',
#  'UMA',
#  'USDC',
#  'USDT',
#  'VET',
#  'WBTC',
#  'XEM',
#  'XLM',
#  'XMR',
#  'XRP',
#  'XTZ',
#  'YFI',
#  'ZEC'}

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# coinfrom    ADA
# cointo      ADA
# corr        1.0
# Name: 0, dtype: object
# coinfrom        ALGO
# cointo           ADA
# corr        0.553742
# Name: 1, dtype: object
# coinfrom        ATOM
# cointo           ADA
# corr        0.544778
# Name: 2, dtype: object
# coinfrom         BCH
# cointo           ADA
# corr        0.487691
# Name: 3, dtype: object
# coinfrom         BNB
# cointo           ADA
# corr        0.402013
# Name: 4, dtype: object
# coinfrom         BSV
# cointo           ADA
# corr        0.407859
# Name: 5, dtype: object
# coinfrom         BTC
# cointo           ADA
# corr        0.475343
# Name: 6, dtype: object
# coinfrom         CRO
# cointo           ADA
# corr        0.414101
# Name: 7, dtype: object
# coinfrom        DASH
# cointo           ADA
# corr        0.419372
# Name: 8, dtype: object
# coinfrom         DOT
# cointo           ADA
# corr        0.449677
# Name: 9, dtype: object
# coinfrom         EOS
# cointo           ADA
# corr        0.538506
# ...
